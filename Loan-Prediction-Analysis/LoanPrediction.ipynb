# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('Loan_Data.csv')
df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#changing categorical values
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mean())

df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
df['Married']=df['Married'].fillna(df['Married'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# # Visulaiztion of categorical attributes

# %%
count=df["Gender"].value_counts()
plt.bar(count.index,count.values)
plt.show()

# %%
count=df["Married"].value_counts()
plt.bar(count.index,count.values)
plt.show()

# %%
count=df["Dependents"].value_counts()
plt.bar(count.index,count.values)
plt.show()

# %%
count=df["Education"].value_counts()
plt.bar(count.index,count.values)
plt.show()

# %%
count=df["Self_Employed"].value_counts()
plt.bar(count.index,count.values)
plt.show()

# %%
count=df["Property_Area"].value_counts()
plt.bar(count.index,count.values)
plt.show()

# %%
count=df["Loan_Status"].value_counts()
plt.bar(count.index,count.values)
plt.show()

# %% [markdown]
# # Visulaiztion of numerical attributes

# %%
sns.distplot(df["ApplicantIncome"])

# %%
sns.distplot(df["CoapplicantIncome"])

# %%
sns.distplot(df["LoanAmount"])

# %%
sns.distplot(df["Loan_Amount_Term"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-4dbe33150db2> in <module>
# ----> 1 sns.distplot(df["Loan_Amount_Term"])
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     231     if kde:
#     232         kde_color = kde_kws.pop("color", color)
# ...

# %%
sns.distplot(df["Credit_History"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-29-8de6f718af99> in <module>
# ----> 1 sns.distplot(df["Credit_History"])
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     231     if kde:
#     232         kde_color = kde_kws.pop("color", color)
# ...

# %%
#We need to create a new attribute named TotalIncome, which will be the addition of ApplicantIncome and CoapplicantIncome.

#Creating a new column TotalIncome
df["TotalIncome"]=df["ApplicantIncome"]+df["CoapplicantIncome"]
df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# ...

# %% [markdown]
# As in the above numerical values all of them are left skewed,so we need to normalize them in order to continue. We will normalize them via log transformation.We will be creating a new column which will store the log of the column values.

# %%
#Creating new attributes
df["ApplicantIncomeLog"]=np.log(df["ApplicantIncome"])
sns.distplot(df["ApplicantIncomeLog"])

# %%
df["CoapplicantIncomeLog"]=np.log(df["CoapplicantIncome"])

# %%
sns.distplot(df["CoapplicantIncomeLog"])

# %%
df["LoanAmountLog"]=np.log(df["LoanAmount"])
sns.distplot(df["LoanAmountLog"])

# %%
df["Loan_Amount_TermLog"]=np.log(df["Loan_Amount_Term"])
sns.distplot(df["Loan_Amount_TermLog"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-40-b97ec72d87e8> in <module>
#       1 df["Loan_Amount_TermLog"]=np.log(df["Loan_Amount_Term"])
# ----> 2 sns.distplot(df["Loan_Amount_TermLog"])
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     231     if kde:
# ...

# %%
df["TotalIncomeLog"]=np.log(df["TotalIncome"])
sns.distplot(df["TotalIncomeLog"])

# %% [markdown]
# # Coorealation Matrix

# %%
#Finding the highly correlated columns and dropping those unnecessary columns.
corr=df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True,cmap="BuPu")

# %%
#drop unnecessary columns
#cols=["ApplicantIncome","CoapplicantIncome","LoanAmount","Loan_Amount_Term","TotalIncome","Loan_ID","CoapplicantIncomeLog"]
#df=df.drop(columns=cols,axis=1)
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        0           0          0              0             1.0
# 1       1        1           1          0              0             1.0
# 2       1        1           0          0              1             1.0
# 3       1        1           0          1              0             1.0
# 4       1        0           0          0              0             1.0
#
#    Property_Area  Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0              2            1            8.674026       4.986426
# 1              0            0            8.430109       4.852030
# 2              2            1            8.006368       4.189655
# 3              2            1            7.856707       4.787492
# 4              2            1            8.699515       4.948760
#
#    Loan_Amount_TermLog  TotalIncomeLog
# 0             5.886104        8.674026
# 1             5.886104        8.714568
# ...

# %% [markdown]
# # Label Encoding

# %%
#changing non numerical values to numerical values
from sklearn.preprocessing import LabelEncoder
cols=["Gender","Married","Dependents","Education","Self_Employed","Property_Area","Loan_Status"]
le=LabelEncoder()
for col in cols:
    df[col]=le.fit_transform(df[col])

# %% [markdown]
# # Splitting training and testing data

# %%
#specify input and output columns
x=df.drop(columns=["Loan_Status"],axis=1)
y=df["Loan_Status"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %% [markdown]
# # Model Training

# %%
#declare a function to reuse the code
from sklearn.model_selection import cross_val_score
def classify(model,x,y):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)
    model.fit(x_train,y_train)
    print("Accuracy = ",model.score(x_test,y_test)*100)
    #cross validation it's used for better validation
    score = cross_val_score(model,x,y,cv=5)
    print("Cross validation is : ",np.mean(score)*100)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
classify(model,x,y)
# Out:
# Accuracy =  77.27272727272727
# Cross validation is :  80.9462881514061

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
classify(model,x,y)
# Out:
# Accuracy =  74.02597402597402
# Cross validation is :  71.99120351859256

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
model = RandomForestClassifier()
classify(model,x,y)
# Out:
# Accuracy =  78.57142857142857
# Cross validation is :  78.01412768226041

# %%
model = ExtraTreesClassifier()
classify(model,x,y)
# Out:
# Accuracy =  71.42857142857143
# Cross validation is :  77.20378515260563

# %% [markdown]
# # Hyperparameter tuning

# %%
model = RandomForestClassifier(n_estimators=200,min_samples_split=25,max_depth=7,max_features=1)
classify(model,x,y)
# Out:
# Accuracy =  75.32467532467533
# Cross validation is :  80.62108489937359

# %% [markdown]
# # Confusion Matrix

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1d4761d92f0b> in <module>
#       1 from sklearn.linear_model import LogisticRegression
#       2 model = LogisticRegression()
# ----> 3 classify(model,x,y)
#       4 model.fit(x_train,y_train)
#
# NameError: name 'classify' is not defined

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[24, 30],
#        [ 2, 98]], dtype=int64)

# %%
sns.heatmap(cm,annot=True)

# %% [markdown]
# In the above heatmap the left sided values are the actual values and the bottom side values are the predicted values.For actual values 0 means no and 1 means yes. So it has predicted 24 no values correctly and 99 yes values correctly. We have mispredicted 2 values for 0 and 30 values for 1. So we need to train better for class 0. Like this we can get an assumption from confusion matrix.
